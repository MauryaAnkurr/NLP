# %%
#The nlp function from spacy automatically takes raw text and performs
#a series of operatios to tag parse and describe the text data.
import spacy
nlp =spacy.load('en_core_web_sm')

# %%
myfile = open("TextDocuments.txt")
text = myfile.read()
myfile.close()

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text,"++",token.pos_)
    print("++++++++++++++")
# Out:
# " ++ PUNCT
# ++++++++++++++
# Job ++ PROPN
# ++++++++++++++
# ID ++ PROPN
# ++++++++++++++
# : ++ PUNCT
# ++++++++++++++
# 168797 ++ NUM
# ++++++++++++++
#
#
#  ++ SPACE
# ++++++++++++++
# Store ++ PROPN
# ++++++++++++++
# Name ++ PROPN
# ++++++++++++++
# / ++ SYM
# ++++++++++++++
# Number ++ NOUN
# ++++++++++++++
# : ++ PUNCT
# ++++++++++++++
# MI ++ PROPN
# ++++++++++++++
# - ++ PUNCT
# ++++++++++++++
# Somerset ++ PROPN
# ++++++++++++++
# ( ++ PUNCT
# ++++++++++++++
# 0266 ++ NUM
# ++++++++++++++
# ) ++ PUNCT
# ++++++++++++++
#
#
#  ++ SPACE
# ++++++++++++++
# Address ++ PROPN
# ++++++++++++++
# : ++ PUNCT
# ++++++++++++++
# 2800 ++ NUM
# ++++++++++++++
# W. ++ PROPN
# ++++++++++++++
# Big ++ PROPN
# ++++++++++++++
# Beaver ++ PROPN
# ++++++++++++++
# Road ++ PROPN
# ++++++++++++++
# # ++ SYM
# ++++++++++++++
# 218 ++ NUM
# ++++++++++++++
# , ++ PUNCT
# ++++++++++++++
# Troy ++ PROPN
# ++++++++++++++
# , ++ PUNCT
# ++++++++++++++
# MI ++ PROPN
# ++++++++++++++
# 48084 ++ NUM
# ...

# %%
nlp.pipe_names
# Out:
# ['tagger', 'parser', 'ner']

# %%
doc2 = nlp(u"tesla isn't looking in to startups anymore.")
for token in doc2:
    print(token.text,token.pos_,token.dep_)
# Out:
# tesla PROPN nsubj
# is VERB aux
# n't ADV neg
# looking VERB ROOT
# in PART prt
# to ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc = nlp(text)
for sentence in doc.sents:
    print("++++++++++++++++++++++++++")
    print(sentence)
# Out:
# ++++++++++++++++++++++++++
# "Job ID: 168797
#
# Store Name/Number: MI-Somerset (0266)
#
#
# ++++++++++++++++++++++++++
# Address:
# ++++++++++++++++++++++++++
# 2800 W. Big Beaver Road #218, Troy, MI 48084, United States (US)
#
#
# ++++++++++++++++++++++++++
# Hourly/Salaried:
# ++++++++++++++++++++++++++
# Hourly
# ++++++++++++++++++++++++++
# (Non-Exempt)
#
# Full Time/Part Time:
# ++++++++++++++++++++++++++
# Part Time
#
# Position Type:
# ++++++++++++++++++++++++++
# Regular
#
# Sephora Stores
#
#
# ++++++++++++++++++++++++++
# It's all about our clients.
# ++++++++++++++++++++++++++
# That's where you come in, to guide her on her beauty journey.
# ++++++++++++++++++++++++++
# It takes energy and confidence and teamwork.
# ++++++++++++++++++++++++++
# It takes authentic passionâ€¦not just about product, but about making a client's day through teaching, inspiring, and playingâ€”together.
# ++++++++++++++++++++++++++
# ...

# %%
import spacy
nlp =spacy.load('en_core_web_sm')

# %%
mystring ='"We\'re moving to L.A.!"'

mystring
# Out:
# '"We\'re moving to L.A.!"'

# %%
doc = nlp(mystring)

for token in doc:
    print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u'We are here to help! Send snail-mail,email support@oursite.com or visit us at http://www.google.com')
for token in doc2:
    print(token.text)
# Out:
# We
# are
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.google.com

# %%
doc3 = nlp(u'A 5km NYC cab ride cost $10.30')
for token in doc3:
    print(token.text)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# cost
# $
# 10.30

# %%
doc4 = nlp(u'Let\'s visit St. Louis in the U.S. next year.')
for token in doc4:
    print(token.text)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
doc5 = nlp(u'Apple to build a Hong Kong factory for $6 million.')
for token in doc5:
    print(token.text,end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million | . |

# %%
# named entity 
doc5 = nlp(u'Apple to build a Hong Kong factory for $6 million.')
for ent in doc5.ents:
    print(ent)
    print(ent.label_)
    print(str(spacy.explain(ent.label_)))
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
# Hong Kong
# GPE
# Countries, cities, states
# $6 million
# MONEY
# Monetary values, including unit

# %%
doc = nlp(text)

# %%
for ent in doc.noun_chunks:
    print(ent)
# Out:
# "Job ID
# 168797
#
# Store Name/Number
# MI-Somerset
# Address
# (US
# Hourly/Salaried
# Hourly
# (Non-Exempt)
#
# Full Time/Part Time
# Part Time
#
# Position Type
# Regular
#
# Sephora Stores
# It
# our clients
# you
# her
# her beauty journey
# It
# energy
# confidence
# teamwork
# It
# product
# a client's day
# teaching
# playingâ€”together
# It
# skill
# Sephora
# our associates
# unparalleled training
# You
# the passion
# we
# you
# everything
# you
# Your role
# Sephora
# a Cashier
# you
# payment
# exchanges
# returns
# other transactions
# clients
# You
# courteous, knowledgeable service
# the cash wrap
# addition
# you
# * Complete transactions
# Ensure clients
# our Beauty Insider program
# additional training
# yourself
# help
# new cashiers
# they
# * Communicate inventory issues
# zone
# proper leadership
# * Maintain store standards
# cleanliness
# organization
# the cashier zone
# assist
# back
# the store
# stock room
# lockers
# kitchen
# bathroom
# ...

# %%
from spacy import displacy
doc = nlp(u'Apple is going to build U.K. factory for $6 Million')
displacy.render(doc,style='dep',jupyter=True,options={'distance':70})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="142-0" class="displacy" width="820" height="242.0" style="max-width: none; height: 242.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="120">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="120">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="152.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# ...

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc,style='ent',jupyter=True,options={'distance':70})
# Out:
# <div class="entities" style="line-height: 2.5">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# ...

# %%
#Stemming
import nltk
from nltk.stem.porter import PorterStemmer
p_stammer = PorterStemmer()

# %%
words =['run','runner','ran','runs','easily','fairly']
for word in words:
    print(word+'-------->',p_stammer.stem(word))
# Out:
# run--------> run
# runner--------> runner
# ran--------> ran
# runs--------> run
# easily--------> easili
# fairly--------> fairli

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')
for word in words:
    print(word+'-------->',s_stemmer.stem(word))
# Out:
# run--------> run
# runner--------> runner
# ran--------> ran
# runs--------> run
# easily--------> easili
# fairly--------> fair

# %%
doc1 = nlp(u'I am a runner running in a race because I love to run since I ran today.')
for token in doc1:
    print(token.text,token.pos_,token.lemma,token.lemma_,end='\t')
# Out:
# I PRON 561228191312463089 -PRON-	am VERB 10382539506755952630 be	a DET 11901859001352538922 a	runner NOUN 12640964157389618806 runner	running VERB 12767647472892411841 run	in ADP 3002984154512732771 in	a DET 11901859001352538922 a	race NOUN 8048469955494714898 race	because ADP 16950148841647037698 because	I PRON 561228191312463089 -PRON-	love VERB 3702023516439754181 love	to PART 3791531372978436496 to	run VERB 12767647472892411841 run	since ADP 10066841407251338481 since	I PRON 561228191312463089 -PRON-	ran VERB 12767647472892411841 run	today NOUN 11042482332948150395 today	. PUNCT 12646065887601541794 .
